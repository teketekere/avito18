# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gc
import os
import pickle
from datetime import datetime as dt
# %matplotlib inline

import lightgbm as lgb
from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import LabelEncoder

categorical = []
NFOLDS = 3
Seedarray = range(NFOLDS)

# %%
def rmse(y, y0):
    assert len(y) == len(y0)
    return np.sqrt(np.mean(np.power((y - y0), 2)))

def get_lgb_model(Dtrain, Dvalid, numiter=1500, isValid=True, randomseed=0):
    lgbm_params = {'task': 'train',
                    'boosting_type': 'gbdt',
                    'objective': 'regression',
                    'metric': 'rmse',
                    #'max_depth': 15,
                    'num_leaves': 270,
                    'feature_fraction': 0.5,
                    'bagging_fraction': 0.75,
                    'bagging_freq': 2,
                    'learning_rate': 0.016,
                    'seed': randomseed
                  }
    evals_results = {}
    # Train lgb
    if isValid == True:
        lgb_clf = lgb.train(lgbm_params,
                            Dtrain,
                            valid_sets=[Dvalid],
                            valid_names=['valid'],
                            num_boost_round=numiter,
                            early_stopping_rounds=50,
                            verbose_eval=50,
                            evals_result=evals_results,
                            feval=None
                           )
    else:
        lgb_clf = lgb.train(lgbm_params,
                            Dtrain,
                            valid_sets=[Dvalid],
                            valid_names=['valid'],
                            num_boost_round=numiter,
                            verbose_eval=100,
                            feval=None
                           )
    # Plot importances
    lgb.plot_importance(lgb_clf, importance_type="split", title="split", figsize=(25, 25))
    plt.show()
    lgb.plot_importance(lgb_clf, importance_type="gain", title='gain', figsize=(25, 25))
    plt.show()

    best_iteration = lgb_clf.best_iteration
    print(f'best iteration is {best_iteration}')
    if isValid:
        best_score = evals_results['valid']['rmse'][lgb_clf.best_iteration-1]
        print(f'best score is {best_score}')
    return lgb_clf, best_iteration

def get_lgb_train(trainX, trainy, validX, validy, predictors, categorical):
    Dtrain = lgb.Dataset(trainX.values, label=trainy.values.ravel(), feature_name=predictors, categorical_feature=categorical)
    Dvalid = lgb.Dataset(validX.values, label=validy.values.ravel(), feature_name=predictors, categorical_feature=categorical)
    return Dtrain, Dvalid

# %%
# Example For KFold
EnableSubmit = False
NFOLDS = 3
numiter = 500

train = pd.read_feather('../features/train/Single_agg_1_train.feather')
temptrain = pd.read_feather('../features/train/Single_agg_2_train.feather')
train = pd.concat([train, temptrain], axis=1)
temptrain = pd.read_feather('../features/train/Single_agg_3_train.feather')
train = pd.concat([train, temptrain], axis=1)
temptrain = pd.read_feather('../features/train/Single_agg_4_train.feather')
train = pd.concat([train, temptrain], axis=1)
del temptrain; gc.collect()
y = pd.read_csv('../input/train.csv', usecols=['deal_probability'])

kf = KFold(n_splits=NFOLDS)
lgb_models = []
best_iters = []
feature_imp_split = []
feature_imp_gain = []
print(train.shape)
print(y.shape)
preds = pd.DataFrame()
predictors = train.columns.tolist()

for count, indices in enumerate(kf.split(train, y)):
    train_idx = indices[0]
    valid_idx = indices[1]
    Dtrain, Dvalid = get_lgb_train(train.iloc[train_idx,:], y.iloc[train_idx,:], train.iloc[valid_idx,:], y.iloc[valid_idx,:], predictors, categorical)
    del train, y; gc.collect()
    lgb_model, bestiter = get_lgb_model(Dtrain, Dvalid, numiter=numiter, isValid=True, randomseed=76)
    del Dtrain, Dvalid; gc.collect()

    if EnableSubmit == True:
        test = pd.read_feather('../')
        preds['lgb_pred_kfold_'+str(count)] = lgb_model.predict(test[predictors], num_iteration=best_iter)
        del test; gc.collect()
    
    lgb_models.append(lgb_model)
    best_iters.append(bestiter)
    fcols = lgb_model.feature_name()
    fimps = lgb_model.feature_importance(importance_type='split')
    feature_imp_split.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})
    fimps = lgb_model.feature_importance(importance_type='gain')
    feature_imp_gain.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})
    
    train = pd.read_feather('../features/train/Single_agg_1_train.feather')
    temptrain = pd.read_feather('../features/train/Single_agg_2_train.feather')
    train = pd.concat([train, temptrain], axis=1)
    temptrain = pd.read_feather('../features/train/Single_agg_3_train.feather')
    train = pd.concat([train, temptrain], axis=1)
    temptrain = pd.read_feather('../features/train/Single_agg_4_train.feather')
    train = pd.concat([train, temptrain], axis=1)
    del temptrain; gc.collect()
    y = pd.read_csv('../input/train.csv', usecols=['deal_probability'])

del train, y
gc.collect()

print('Best iterations:')
print(best_iters)
#print('Feature Importtance Split')
#print(feature_imp_split)
#print('Feature Importtance Gain')
#print(feature_imp_gain)

if EnableSubmit == True:
    subs = pd.read_csv('../input/test.csv', usecols=['item_id'])

    pred_ensemble = np.zeros_like(preds['lgb_pred_kfold_0'].values)
    for col in preds.columns:
        pred_ensemble += preds[col].values
    pred_ensemble /= np.float(NFOLDS)
    pred_ensemble = np.clip(pred_ensemble, 0, 1)
    subs['deal_probability'] = pred_ensemble.flatten()

    datetime = dt.now().strftime('%Y_%m%d_%H%M_%S')
    fileprefix = '../subs/lightgbm_kfold_ensemble_'
    filename = fileprefix+datetime+'.csv.gz'
    subs.to_csv(filename, index=False, float_format='%.9f', compression='gzip')
    with open(fileprefix+datetime+'_fimp_split.pickle', 'wb') as f:
        pickle.dump(feature_imp_split, f)
    with open(fileprefix+datetime+'_fimp_gain.pickle', 'wb') as f:
        pickle.dump(feature_imp_gain, f)

    del subs; gc.collect()
del lgb_models, best_iters, feature_imp_split, feature_imp_gain; gc.collect()
# Out:
# (1503424, 162)
# (1503424, 1)
# C:\Users\osk\Anaconda3\envs\InqueryAnalysis\lib\site-packages\lightgbm\basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds.
# [50]	valid's rmse: 0.239147
# [100]	valid's rmse: 0.234375
# [150]	valid's rmse: 0.233139
# [200]	valid's rmse: 0.232701
# [250]	valid's rmse: 0.23251
# [300]	valid's rmse: 0.232392
# [350]	valid's rmse: 0.232329
# [400]	valid's rmse: 0.232275
# [450]	valid's rmse: 0.232241
# [500]	valid's rmse: 0.232214
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 0.232214
# best iteration is 500
# best score is 0.23221444610489145
# Training until validation scores don't improve for 50 rounds.
# [50]	valid's rmse: 0.239094
# [100]	valid's rmse: 0.234418
# [150]	valid's rmse: 0.23326
# [200]	valid's rmse: 0.232868
# [250]	valid's rmse: 0.232673
# [300]	valid's rmse: 0.232574
# [350]	valid's rmse: 0.232507
# [400]	valid's rmse: 0.232464
# [450]	valid's rmse: 0.232444
# [500]	valid's rmse: 0.232427
# Did not meet early stopping. Best iteration is:
# [494]	valid's rmse: 0.232426
# best iteration is 494
# best score is 0.23242640056420216
# Training until validation scores don't improve for 50 rounds.
# [50]	valid's rmse: 0.240202
# [100]	valid's rmse: 0.235389
# [150]	valid's rmse: 0.234115
# [200]	valid's rmse: 0.233684
# [250]	valid's rmse: 0.233474
# [300]	valid's rmse: 0.233352
# [350]	valid's rmse: 0.233282
# [400]	valid's rmse: 0.233227
# [450]	valid's rmse: 0.233195
# [500]	valid's rmse: 0.233173
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 0.233172
# best iteration is 499
# best score is 0.23317196521288813
# Best iterations:
# [500, 494, 499]
# Feature Importtance Split
# [{'region_numcount': 1493, 'city_numcount': 1404, 'parent_category_name_numcount': 718, 'category_name_numcount': 1192, 'user_type_numcount': 163, 'weekofday_numcount': 747, 'param_1_numcount': 2203, 'param_123_numcount': 2396, 'region_city_numcount': 1024, 'region_parent_category_name_numcount': 1541, 'region_category_name_numcount': 1158, 'region_user_type_numcount': 1006, 'region_weekofday_numcount': 2475, 'region_param_1_numcount': 1147, 'region_param_123_numcount': 1265, 'city_parent_category_name_numcount': 1388, 'city_category_name_numcount': 1145, 'city_user_type_numcount': 1527, 'city_weekofday_numcount': 1869, 'city_param_1_numcount': 1142, 'city_param_123_numcount': 1268, 'parent_category_name_category_name_numcount': 484, 'parent_category_name_user_type_numcount': 537, 'parent_category_name_weekofday_numcount': 1407, 'parent_category_name_param_1_numcount': 1013, 'parent_category_name_param_123_numcount': 1380, 'category_name_user_type_numcount': 969, 'category_name_weekofday_numcount': 1216, 'category_name_param_1_numcount': 941, 'category_name_param_123_numcount': 1183, 'user_type_weekofday_numcount': 822, 'user_type_param_1_numcount': 1101, 'user_type_param_123_numcount': 1519, 'weekofday_param_1_numcount': 1338, 'weekofday_param_123_numcount': 1209, 'param_1_param_123_numcount': 490, 'region_city_parent_category_name_numcount': 791, 'region_city_category_name_numcount': 733, 'region_city_user_type_numcount': 980, 'region_city_weekofday_numcount': 1095, 'region_city_param_1_numcount': 669, 'region_city_param_123_numcount': 589, 'region_parent_category_name_category_name_numcount': 681, 'region_parent_category_name_user_type_numcount': 1085, 'region_parent_category_name_weekofday_numcount': 1719, 'region_parent_category_name_param_1_numcount': 835, 'region_parent_category_name_param_123_numcount': 832, 'region_category_name_user_type_numcount': 1110, 'region_category_name_weekofday_numcount': 1658, 'region_category_name_param_1_numcount': 838, 'region_category_name_param_123_numcount': 674, 'region_user_type_weekofday_numcount': 1859, 'region_user_type_param_1_numcount': 931, 'region_user_type_param_123_numcount': 1315, 'region_weekofday_param_1_numcount': 1530, 'region_weekofday_param_123_numcount': 1412, 'region_param_1_param_123_numcount': 259, 'city_parent_category_name_category_name_numcount': 436, 'city_parent_category_name_user_type_numcount': 1118, 'city_parent_category_name_weekofday_numcount': 1450, 'city_parent_category_name_param_1_numcount': 588, 'city_parent_category_name_param_123_numcount': 544, 'city_category_name_user_type_numcount': 1378, 'city_category_name_weekofday_numcount': 1554, 'city_category_name_param_1_numcount': 527, 'city_category_name_param_123_numcount': 435, 'city_user_type_weekofday_numcount': 1811, 'city_user_type_param_1_numcount': 1104, 'city_user_type_param_123_numcount': 1089, 'city_weekofday_param_1_numcount': 1305, 'city_weekofday_param_123_numcount': 1073, 'city_param_1_param_123_numcount': 165, 'parent_category_name_category_name_user_type_numcount': 437, 'parent_category_name_category_name_weekofday_numcount': 503, 'parent_category_name_category_name_param_1_numcount': 453, 'parent_category_name_category_name_param_123_numcount': 397, 'parent_category_name_user_type_weekofday_numcount': 1198, 'parent_category_name_user_type_param_1_numcount': 737, 'parent_category_name_user_type_param_123_numcount': 797, 'parent_category_name_weekofday_param_1_numcount': 787, 'parent_category_name_weekofday_param_123_numcount': 916, 'parent_category_name_param_1_param_123_numcount': 242, 'category_name_user_type_weekofday_numcount': 1103, 'category_name_user_type_param_1_numcount': 536, 'category_name_user_type_param_123_numcount': 745, 'category_name_weekofday_param_1_numcount': 811, 'category_name_weekofday_param_123_numcount': 650, 'category_name_param_1_param_123_numcount': 148, 'user_type_weekofday_param_1_numcount': 998, 'user_type_weekofday_param_123_numcount': 1163, 'user_type_ ...
# Feature Importtance Gain
# [{'region_numcount': 1391.5269163250923, 'city_numcount': 1395.7648209631443, 'parent_category_name_numcount': 21013.110821276903, 'category_name_numcount': 68994.01305523515, 'user_type_numcount': 4362.901541441679, 'weekofday_numcount': 486.0586271136999, 'param_1_numcount': 20024.227239578962, 'param_123_numcount': 8470.603533610702, 'region_city_numcount': 1274.837443396449, 'region_parent_category_name_numcount': 2711.325028270483, 'region_category_name_numcount': 1301.4995101988316, 'region_user_type_numcount': 1446.942130073905, 'region_weekofday_numcount': 2042.4678726792336, 'region_param_1_numcount': 1209.0064148902893, 'region_param_123_numcount': 1354.7770193815231, 'city_parent_category_name_numcount': 1338.2555322051048, 'city_category_name_numcount': 1051.772092655301, 'city_user_type_numcount': 1629.0695451796055, 'city_weekofday_numcount': 1558.1394821703434, 'city_param_1_numcount': 1072.325186446309, 'city_param_123_numcount': 1250.7099160552025, 'parent_category_name_category_name_numcount': 27188.488768473268, 'parent_category_name_user_type_numcount': 9324.366729617119, 'parent_category_name_weekofday_numcount': 11155.331222623587, 'parent_category_name_param_1_numcount': 7181.7543223798275, 'parent_category_name_param_123_numcount': 3840.465546965599, 'category_name_user_type_numcount': 20384.81353841722, 'category_name_weekofday_numcount': 6927.84526334703, 'category_name_param_1_numcount': 4375.099978938699, 'category_name_param_123_numcount': 3290.9489465504885, 'user_type_weekofday_numcount': 4235.055567979813, 'user_type_param_1_numcount': 7144.7832345068455, 'user_type_param_123_numcount': 5367.404795497656, 'weekofday_param_1_numcount': 5131.72098466754, 'weekofday_param_123_numcount': 1642.2507853209972, 'param_1_param_123_numcount': 1269.604601278901, 'region_city_parent_category_name_numcount': 775.317300543189, 'region_city_category_name_numcount': 729.5518527925014, 'region_city_user_type_numcount': 1150.9761121422052, 'region_city_weekofday_numcount': 1058.297332316637, 'region_city_param_1_numcount': 662.1143456995487, 'region_city_param_123_numcount': 582.2884722352028, 'region_parent_category_name_category_name_numcount': 1120.0821832865477, 'region_parent_category_name_user_type_numcount': 1046.0319493561983, 'region_parent_category_name_weekofday_numcount': 1445.391887292266, 'region_parent_category_name_param_1_numcount': 1088.7875132262707, 'region_parent_category_name_param_123_numcount': 1018.7402078211308, 'region_category_name_user_type_numcount': 936.1768846809864, 'region_category_name_weekofday_numcount': 1352.8921485245228, 'region_category_name_param_1_numcount': 1112.814616560936, 'region_category_name_param_123_numcount': 748.4331290125847, 'region_user_type_weekofday_numcount': 1659.2278672903776, 'region_user_type_param_1_numcount': 820.162490233779, 'region_user_type_param_123_numcount': 1252.8923794478178, 'region_weekofday_param_1_numcount': 1213.5042708963156, 'region_weekofday_param_123_numcount': 1130.4390057623386, 'region_param_1_param_123_numcount': 252.08485481142998, 'city_parent_category_name_category_name_numcount': 398.4497880637646, 'city_parent_category_name_user_type_numcount': 1022.5705929100513, 'city_parent_category_name_weekofday_numcount': 1120.4771735966206, 'city_parent_category_name_param_1_numcount': 590.3425292372704, 'city_parent_category_name_param_123_numcount': 477.37875796854496, 'city_category_name_user_type_numcount': 1255.757194340229, 'city_category_name_weekofday_numcount': 1178.730934470892, 'city_category_name_param_1_numcount': 493.3835223466158, 'city_category_name_param_123_numcount': 430.4943204522133, 'city_user_type_weekofday_numcount': 1532.7596583664417, 'city_user_type_param_1_numcount': 1149.4816538095474, 'city_user_type_param_123_numcount': 1071.356542095542, 'city_weekofday_param_1_numcount': 1042.3626555800438, 'city_weekofday_param_123_numcount': 887.5411089360714, 'city_param_1_param_123_numcount': 183.85112649202347, ...
# 0

# %%
# Example For whole traindata
EnableSubmit = False
numiter = 500

train = pd.read_feather('../features/train/Single_agg_1_train.feather')
temptrain = pd.read_feather('../features/train/Single_agg_2_train.feather')
train = pd.concat([train, temptrain], axis=1)
temptrain = pd.read_feather('../features/train/Single_agg_3_train.feather')
train = pd.concat([train, temptrain], axis=1)
temptrain = pd.read_feather('../features/train/Single_agg_4_train.feather')
train = pd.concat([train, temptrain], axis=1)
del temptrain; gc.collect()
y = pd.read_csv('../input/train.csv', usecols=['deal_probability'])

print(train.shape)
print(y.shape)

predictors = train.columns.tolist()

Dtrain, Dvalid = get_lgb_train(train, y, train.iloc[:2, :], y.iloc[:2, :], predictors, categorical)
del train, y; gc.collect()
lgb_model, best_iter = get_lgb_model(Dtrain, Dvalid, numiter=numiter, isValid=False, randomseed=98)
del Dtrain; gc.collect()

feature_imp_split = []
feature_imp_gain = []
fcols = lgb_model.feature_name()
fimps = lgb_model.feature_importance(importance_type='split')
feature_imp_split.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})
fimps = lgb_model.feature_importance(importance_type='gain')
feature_imp_gain.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})

#print('Feature Importtance Split')
#print(feature_imp_split)
#print('Feature Importtance Gain')
#print(feature_imp_gain)

datetime = dt.now().strftime('%Y_%m%d_%H%M_%S')
fileprefix = '../subs/lightgbm_kfold_ensemble_'

if EnableSubmit == True:
    subs = pd.read_csv('../input/test.csv', usecols=['item_id'])
    test = get_test_forlgb('../features/featured/test/hoge.feather')
    subs['deal_probability'] = lgb_model.predict(test[predictors], num_iteration=best_iter)
    filename = fileprefix+datetime+'.csv.gz'
    subs.to_csv(filename, index=False, float_format='%.9f', compression='gzip')
    del subs, test; gc.collect()

with open(fileprefix+datetime+'_fimp_split.pickle', 'wb') as f:
    pickle.dump(feature_imp_split, f)
with open(fileprefix+datetime+'_fimp_gain.pickle', 'wb') as f:
    pickle.dump(feature_imp_gain, f)
# Out:
# (1503424, 162)
# (1503424, 1)
# C:\Users\osk\Anaconda3\envs\InqueryAnalysis\lib\site-packages\lightgbm\basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [100]	valid's rmse: 0.108498
# [200]	valid's rmse: 0.111329
# [300]	valid's rmse: 0.115328
# [400]	valid's rmse: 0.119069
# [500]	valid's rmse: 0.119893
# best iteration is 0
# Feature Importtance Split
# [{'region_numcount': 1490, 'city_numcount': 1541, 'parent_category_name_numcount': 877, 'category_name_numcount': 1187, 'user_type_numcount': 192, 'weekofday_numcount': 673, 'param_1_numcount': 2701, 'param_123_numcount': 2918, 'region_city_numcount': 1018, 'region_parent_category_name_numcount': 1709, 'region_category_name_numcount': 1392, 'region_user_type_numcount': 1123, 'region_weekofday_numcount': 2490, 'region_param_1_numcount': 1225, 'region_param_123_numcount': 1339, 'city_parent_category_name_numcount': 1373, 'city_category_name_numcount': 1233, 'city_user_type_numcount': 1363, 'city_weekofday_numcount': 1748, 'city_param_1_numcount': 1191, 'city_param_123_numcount': 1169, 'parent_category_name_category_name_numcount': 670, 'parent_category_name_user_type_numcount': 513, 'parent_category_name_weekofday_numcount': 1328, 'parent_category_name_param_1_numcount': 1062, 'parent_category_name_param_123_numcount': 1710, 'category_name_user_type_numcount': 940, 'category_name_weekofday_numcount': 1277, 'category_name_param_1_numcount': 985, 'category_name_param_123_numcount': 1219, 'user_type_weekofday_numcount': 735, 'user_type_param_1_numcount': 1114, 'user_type_param_123_numcount': 1595, 'weekofday_param_1_numcount': 1411, 'weekofday_param_123_numcount': 1148, 'param_1_param_123_numcount': 566, 'region_city_parent_category_name_numcount': 776, 'region_city_category_name_numcount': 836, 'region_city_user_type_numcount': 1137, 'region_city_weekofday_numcount': 1269, 'region_city_param_1_numcount': 589, 'region_city_param_123_numcount': 637, 'region_parent_category_name_category_name_numcount': 545, 'region_parent_category_name_user_type_numcount': 1134, 'region_parent_category_name_weekofday_numcount': 1751, 'region_parent_category_name_param_1_numcount': 732, 'region_parent_category_name_param_123_numcount': 824, 'region_category_name_user_type_numcount': 986, 'region_category_name_weekofday_numcount': 1628, 'region_category_name_param_1_numcount': 819, 'region_category_name_param_123_numcount': 671, 'region_user_type_weekofday_numcount': 1940, 'region_user_type_param_1_numcount': 947, 'region_user_type_param_123_numcount': 1281, 'region_weekofday_param_1_numcount': 1385, 'region_weekofday_param_123_numcount': 1343, 'region_param_1_param_123_numcount': 215, 'city_parent_category_name_category_name_numcount': 342, 'city_parent_category_name_user_type_numcount': 1282, 'city_parent_category_name_weekofday_numcount': 1299, 'city_parent_category_name_param_1_numcount': 580, 'city_parent_category_name_param_123_numcount': 480, 'city_category_name_user_type_numcount': 1157, 'city_category_name_weekofday_numcount': 1338, 'city_category_name_param_1_numcount': 715, 'city_category_name_param_123_numcount': 426, 'city_user_type_weekofday_numcount': 1916, 'city_user_type_param_1_numcount': 1221, 'city_user_type_param_123_numcount': 1117, 'city_weekofday_param_1_numcount': 1098, 'city_weekofday_param_123_numcount': 933, 'city_param_1_param_123_numcount': 166, 'parent_category_name_category_name_user_type_numcount': 551, 'parent_category_name_category_name_weekofday_numcount': 510, 'parent_category_name_category_name_param_1_numcount': 409, 'parent_category_name_category_name_param_123_numcount': 419, 'parent_category_name_user_type_weekofday_numcount': 1037, 'parent_category_name_user_type_param_1_numcount': 836, 'parent_category_name_user_type_param_123_numcount': 1160, 'parent_category_name_weekofday_param_1_numcount': 819, 'parent_category_name_weekofday_param_123_numcount': 827, 'parent_category_name_param_1_param_123_numcount': 266, 'category_name_user_type_weekofday_numcount': 1183, 'category_name_user_type_param_1_numcount': 515, 'category_name_user_type_param_123_numcount': 789, 'category_name_weekofday_param_1_numcount': 721, 'category_name_weekofday_param_123_numcount': 615, 'category_name_param_1_param_123_numcount': 201, 'user_type_weekofday_param_1_numcount': 877, 'user_type_weekofday_param_123_numcount': 1132, 'user_type_ ...
# Feature Importtance Gain
# [{'region_numcount': 1817.6736851036549, 'city_numcount': 1931.0285153090954, 'parent_category_name_numcount': 37370.488613307476, 'category_name_numcount': 93521.21862262487, 'user_type_numcount': 9108.734025478363, 'weekofday_numcount': 495.3053319454193, 'param_1_numcount': 28396.220431417227, 'param_123_numcount': 12271.453520685434, 'region_city_numcount': 1584.8075572550297, 'region_parent_category_name_numcount': 2231.236980289221, 'region_category_name_numcount': 1645.0254659950733, 'region_user_type_numcount': 1480.735820606351, 'region_weekofday_numcount': 2384.2619849592447, 'region_param_1_numcount': 1581.8670482337475, 'region_param_123_numcount': 1669.2623629570007, 'city_parent_category_name_numcount': 1712.501711577177, 'city_category_name_numcount': 1474.8658062517643, 'city_user_type_numcount': 1833.0495844483376, 'city_weekofday_numcount': 1749.3545511066914, 'city_param_1_numcount': 1422.203776359558, 'city_param_123_numcount': 1391.259597748518, 'parent_category_name_category_name_numcount': 57338.21181461215, 'parent_category_name_user_type_numcount': 13941.6655536443, 'parent_category_name_weekofday_numcount': 13823.967133462429, 'parent_category_name_param_1_numcount': 9175.533789038658, 'parent_category_name_param_123_numcount': 6294.175423055887, 'category_name_user_type_numcount': 21300.505814790726, 'category_name_weekofday_numcount': 16855.275354504585, 'category_name_param_1_numcount': 6448.093167692423, 'category_name_param_123_numcount': 4545.689364910126, 'user_type_weekofday_numcount': 5851.809260904789, 'user_type_param_1_numcount': 8583.198772639036, 'user_type_param_123_numcount': 7332.408258110285, 'weekofday_param_1_numcount': 11626.025891304016, 'weekofday_param_123_numcount': 1999.9656926095486, 'param_1_param_123_numcount': 2019.2918327748775, 'region_city_parent_category_name_numcount': 930.7098225057125, 'region_city_category_name_numcount': 1115.3970320522785, 'region_city_user_type_numcount': 1804.5165630877018, 'region_city_weekofday_numcount': 1348.9815577566624, 'region_city_param_1_numcount': 655.3564201593399, 'region_city_param_123_numcount': 854.4442500770092, 'region_parent_category_name_category_name_numcount': 636.1715311706066, 'region_parent_category_name_user_type_numcount': 1612.785603761673, 'region_parent_category_name_weekofday_numcount': 1836.9753466844559, 'region_parent_category_name_param_1_numcount': 1198.2879073023796, 'region_parent_category_name_param_123_numcount': 1138.2822547852993, 'region_category_name_user_type_numcount': 989.4035284817219, 'region_category_name_weekofday_numcount': 1423.8883532881737, 'region_category_name_param_1_numcount': 1561.4489065408707, 'region_category_name_param_123_numcount': 1404.5376814901829, 'region_user_type_weekofday_numcount': 1731.220925182104, 'region_user_type_param_1_numcount': 942.8889973461628, 'region_user_type_param_123_numcount': 1269.0625367313623, 'region_weekofday_param_1_numcount': 1173.0939212441444, 'region_weekofday_param_123_numcount': 1219.4218999147415, 'region_param_1_param_123_numcount': 325.13157349824905, 'city_parent_category_name_category_name_numcount': 355.35883715748787, 'city_parent_category_name_user_type_numcount': 1446.4653387665749, 'city_parent_category_name_weekofday_numcount': 1173.5999183654785, 'city_parent_category_name_param_1_numcount': 751.5288155376911, 'city_parent_category_name_param_123_numcount': 540.8976767063141, 'city_category_name_user_type_numcount': 1187.3692729473114, 'city_category_name_weekofday_numcount': 1215.215939193964, 'city_category_name_param_1_numcount': 774.3751935362816, 'city_category_name_param_123_numcount': 506.0739845633507, 'city_user_type_weekofday_numcount': 1800.4214687943459, 'city_user_type_param_1_numcount': 1502.9376993179321, 'city_user_type_param_123_numcount': 1247.975399762392, 'city_weekofday_param_1_numcount': 1059.9587778449059, 'city_weekofday_param_123_numcount': 958.3960775732994, 'city_param_1_param_123_numcount': 173.29251903 ...

# %%
len(feature_imp_gain[0])
len(feature_imp_split[0])
sort_gain = sorted(feature_imp_gain[0].items(), key=lambda x: -x[1])
for k, _ in sort_gain[:25]:
    print(k)
# Out:
# category_name_numcount
# parent_category_name_category_name_numcount
# parent_category_name_numcount
# param_1_numcount
# parent_category_name_category_name_user_type_numcount
# category_name_user_type_numcount
# category_name_weekofday_numcount
# parent_category_name_user_type_numcount
# parent_category_name_weekofday_numcount
# param_123_numcount
# weekofday_param_1_numcount
# parent_category_name_category_name_weekofday_numcount
# parent_category_name_param_1_numcount
# user_type_numcount
# user_type_param_1_numcount
# parent_category_name_user_type_param_1_numcount
# parent_category_name_user_type_weekofday_numcount
# user_type_param_123_numcount
# category_name_param_1_numcount
# parent_category_name_param_123_numcount
# user_type_weekofday_numcount
# category_name_param_123_numcount
# parent_category_name_user_type_param_123_numcount
# category_name_user_type_weekofday_numcount
# category_name_user_type_param_123_numcount

# %%
sort_split = sorted(feature_imp_split[0].items(), key=lambda x: -x[1])
for k, _ in sort_split[:25]:
    print(k)
# Out:
# param_123_numcount
# param_1_numcount
# region_weekofday_numcount
# region_user_type_weekofday_numcount
# city_user_type_weekofday_numcount
# region_parent_category_name_weekofday_numcount
# city_weekofday_numcount
# parent_category_name_param_123_numcount
# region_parent_category_name_numcount
# city_category_name_user_type_weekofday_numcount
# city_parent_category_name_user_type_weekofday_numcount
# region_category_name_weekofday_numcount
# user_type_param_123_numcount
# region_parent_category_name_user_type_weekofday_numcount
# city_numcount
# region_numcount
# region_category_name_user_type_weekofday_numcount
# weekofday_param_1_numcount
# city_user_type_weekofday_param_123_numcount
# region_category_name_numcount
# region_weekofday_param_1_numcount
# region_user_type_weekofday_param_1_numcount
# city_parent_category_name_numcount
# city_user_type_numcount
# region_weekofday_param_123_numcount

# %%
gainlist = [k for k, _ in sort_gain[:20]]
splitlist = [k for k, _ in sort_split[:20]]

label_set = set(gainlist+splitlist)
print(len(label_set))
print(label_set)
# Out:
# 35
# {'region_category_name_user_type_weekofday_numcount', 'parent_category_name_param_123_numcount', 'region_category_name_numcount', 'param_123_numcount', 'category_name_numcount', 'category_name_param_1_numcount', 'parent_category_name_user_type_weekofday_numcount', 'parent_category_name_weekofday_numcount', 'city_numcount', 'city_parent_category_name_user_type_weekofday_numcount', 'parent_category_name_category_name_weekofday_numcount', 'user_type_param_1_numcount', 'user_type_numcount', 'user_type_param_123_numcount', 'category_name_user_type_numcount', 'parent_category_name_numcount', 'region_parent_category_name_numcount', 'city_user_type_weekofday_param_123_numcount', 'parent_category_name_category_name_numcount', 'category_name_weekofday_numcount', 'weekofday_param_1_numcount', 'parent_category_name_category_name_user_type_numcount', 'parent_category_name_param_1_numcount', 'param_1_numcount', 'parent_category_name_user_type_numcount', 'city_weekofday_numcount', 'region_parent_category_name_weekofday_numcount', 'region_parent_category_name_user_type_weekofday_numcount', 'city_user_type_weekofday_numcount', 'parent_category_name_user_type_param_1_numcount', 'region_user_type_weekofday_numcount', 'city_category_name_user_type_weekofday_numcount', 'region_weekofday_numcount', 'region_numcount', 'region_category_name_weekofday_numcount'}

# %%
# 分解する
label_list = list(label_set)
label_list = [k[:-9] for k in label_list]
for k in label_list:
    print(k)
# Out:
# region_category_name_user_type_weekofday
# parent_category_name_param_123
# region_category_name
# param_123
# category_name
# category_name_param_1
# parent_category_name_user_type_weekofday
# parent_category_name_weekofday
# city
# city_parent_category_name_user_type_weekofday
# parent_category_name_category_name_weekofday
# user_type_param_1
# user_type
# user_type_param_123
# category_name_user_type
# parent_category_name
# region_parent_category_name
# city_user_type_weekofday_param_123
# parent_category_name_category_name
# category_name_weekofday
# weekofday_param_1
# parent_category_name_category_name_user_type
# parent_category_name_param_1
# param_1
# parent_category_name_user_type
# city_weekofday
# region_parent_category_name_weekofday
# region_parent_category_name_user_type_weekofday
# city_user_type_weekofday
# parent_category_name_user_type_param_1
# region_user_type_weekofday
# city_category_name_user_type_weekofday
# region_weekofday
# region
# region_category_name_weekofday

# %%
label_splits = []
for k in label_list:
    k = k.replace('parent_category_name', 'parentcategoryname')
    k = k.replace('category_name', 'categoryname')
    k = k.replace('user_type', 'usertype')
    k = k.replace('param_123', 'param123')
    k = k.replace('param_1', 'param1')
    label_splits.append(k.split('_'))

for k in label_splits:
    print(k)
# Out:
# ['region', 'categoryname', 'usertype', 'weekofday']
# ['parentcategoryname', 'param123']
# ['region', 'categoryname']
# ['param123']
# ['categoryname']
# ['categoryname', 'param1']
# ['parentcategoryname', 'usertype', 'weekofday']
# ['parentcategoryname', 'weekofday']
# ['city']
# ['city', 'parentcategoryname', 'usertype', 'weekofday']
# ['parentcategoryname', 'categoryname', 'weekofday']
# ['usertype', 'param1']
# ['usertype']
# ['usertype', 'param123']
# ['categoryname', 'usertype']
# ['parentcategoryname']
# ['region', 'parentcategoryname']
# ['city', 'usertype', 'weekofday', 'param123']
# ['parentcategoryname', 'categoryname']
# ['categoryname', 'weekofday']
# ['weekofday', 'param1']
# ['parentcategoryname', 'categoryname', 'usertype']
# ['parentcategoryname', 'param1']
# ['param1']
# ['parentcategoryname', 'usertype']
# ['city', 'weekofday']
# ['region', 'parentcategoryname', 'weekofday']
# ['region', 'parentcategoryname', 'usertype', 'weekofday']
# ['city', 'usertype', 'weekofday']
# ['parentcategoryname', 'usertype', 'param1']
# ['region', 'usertype', 'weekofday']
# ['city', 'categoryname', 'usertype', 'weekofday']
# ['region', 'weekofday']
# ['region']
# ['region', 'categoryname', 'weekofday']

# %%
label_splits2 = []
for ks in label_splits:
    k = '-'.join(ks)
    k = k.replace('parentcategoryname', 'parent_category_name')
    k = k.replace('categoryname', 'category_name')
    k = k.replace('usertype', 'user_type')
    k = k.replace('param123', 'param_123')
    k = k.replace('param1', 'param_1')
    k = k.split('-')
    label_splits2.append(k)

for k in label_splits2:
    print(k)
# Out:
# ['region', 'category_name', 'user_type', 'weekofday']
# ['parent_category_name', 'param_123']
# ['region', 'category_name']
# ['param_123']
# ['category_name']
# ['category_name', 'param_1']
# ['parent_category_name', 'user_type', 'weekofday']
# ['parent_category_name', 'weekofday']
# ['city']
# ['city', 'parent_category_name', 'user_type', 'weekofday']
# ['parent_category_name', 'category_name', 'weekofday']
# ['user_type', 'param_1']
# ['user_type']
# ['user_type', 'param_123']
# ['category_name', 'user_type']
# ['parent_category_name']
# ['region', 'parent_category_name']
# ['city', 'user_type', 'weekofday', 'param_123']
# ['parent_category_name', 'category_name']
# ['category_name', 'weekofday']
# ['weekofday', 'param_1']
# ['parent_category_name', 'category_name', 'user_type']
# ['parent_category_name', 'param_1']
# ['param_1']
# ['parent_category_name', 'user_type']
# ['city', 'weekofday']
# ['region', 'parent_category_name', 'weekofday']
# ['region', 'parent_category_name', 'user_type', 'weekofday']
# ['city', 'user_type', 'weekofday']
# ['parent_category_name', 'user_type', 'param_1']
# ['region', 'user_type', 'weekofday']
# ['city', 'category_name', 'user_type', 'weekofday']
# ['region', 'weekofday']
# ['region']
# ['region', 'category_name', 'weekofday']

# %%
with open('./Golden_Count_aggs.pickle', 'wb') as f:
    pickle.dump(label_splits2, f)

# %%
# Example For KFold
EnableSubmit = False
NFOLDS = 3
numiter = 500

train = pd.read_feather('../features/train/Agg_count_Golden_features_train.feather')
y = pd.read_csv('../input/train.csv', usecols=['deal_probability'])

kf = KFold(n_splits=NFOLDS)
lgb_models = []
best_iters = []
feature_imp_split = []
feature_imp_gain = []
print(train.shape)
print(y.shape)
preds = pd.DataFrame()
predictors = train.columns.tolist()

for count, indices in enumerate(kf.split(train, y)):
    train_idx = indices[0]
    valid_idx = indices[1]
    Dtrain, Dvalid = get_lgb_train(train.iloc[train_idx,:], y.iloc[train_idx,:], train.iloc[valid_idx,:], y.iloc[valid_idx,:], predictors, categorical)
    del train, y; gc.collect()
    lgb_model, bestiter = get_lgb_model(Dtrain, Dvalid, numiter=numiter, isValid=True, randomseed=76)
    del Dtrain, Dvalid; gc.collect()

    if EnableSubmit == True:
        test = pd.read_feather('../')
        preds['lgb_pred_kfold_'+str(count)] = lgb_model.predict(test[predictors], num_iteration=best_iter)
        del test; gc.collect()
    
    lgb_models.append(lgb_model)
    best_iters.append(bestiter)
    fcols = lgb_model.feature_name()
    fimps = lgb_model.feature_importance(importance_type='split')
    feature_imp_split.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})
    fimps = lgb_model.feature_importance(importance_type='gain')
    feature_imp_gain.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})
    
    train = pd.read_feather('../features/train/Agg_count_Golden_features_train.feather')
    y = pd.read_csv('../input/train.csv', usecols=['deal_probability'])

del train, y
gc.collect()

print('Best iterations:')
print(best_iters)

if EnableSubmit == True:
    subs = pd.read_csv('../input/test.csv', usecols=['item_id'])

    pred_ensemble = np.zeros_like(preds['lgb_pred_kfold_0'].values)
    for col in preds.columns:
        pred_ensemble += preds[col].values
    pred_ensemble /= np.float(NFOLDS)
    pred_ensemble = np.clip(pred_ensemble, 0, 1)
    subs['deal_probability'] = pred_ensemble.flatten()

    datetime = dt.now().strftime('%Y_%m%d_%H%M_%S')
    fileprefix = '../subs/lightgbm_kfold_ensemble_'
    filename = fileprefix+datetime+'.csv.gz'
    subs.to_csv(filename, index=False, float_format='%.9f', compression='gzip')

    del subs; gc.collect()
# Out:
# (1503424, 35)
# (1503424, 1)
# C:\Users\osk\Anaconda3\envs\InqueryAnalysis\lib\site-packages\lightgbm\basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds.
# [50]	valid's rmse: 0.23947
# [100]	valid's rmse: 0.234724
# [150]	valid's rmse: 0.233468
# [200]	valid's rmse: 0.233029
# [250]	valid's rmse: 0.232813
# [300]	valid's rmse: 0.23269
# [350]	valid's rmse: 0.232607
# [400]	valid's rmse: 0.232546
# [450]	valid's rmse: 0.232508
# [500]	valid's rmse: 0.232477
# Did not meet early stopping. Best iteration is:
# [500]	valid's rmse: 0.232477
# best iteration is 500
# best score is 0.23247698557118424
# Training until validation scores don't improve for 50 rounds.
# [50]	valid's rmse: 0.239428
# [100]	valid's rmse: 0.234789
# [150]	valid's rmse: 0.233589
# [200]	valid's rmse: 0.233174
# [250]	valid's rmse: 0.23298
# [300]	valid's rmse: 0.232871
# [350]	valid's rmse: 0.232785
# [400]	valid's rmse: 0.23273
# [450]	valid's rmse: 0.232689
# [500]	valid's rmse: 0.232666
# Did not meet early stopping. Best iteration is:
# [499]	valid's rmse: 0.232665
# best iteration is 499
# best score is 0.23266548041055318
# Training until validation scores don't improve for 50 rounds.
# [50]	valid's rmse: 0.240472
# [100]	valid's rmse: 0.235662
# [150]	valid's rmse: 0.234372
# [200]	valid's rmse: 0.23392
# [250]	valid's rmse: 0.233708
# [300]	valid's rmse: 0.233576
# [350]	valid's rmse: 0.23349
# [400]	valid's rmse: 0.233432
# [450]	valid's rmse: 0.233398
# [500]	valid's rmse: 0.233367
# Did not meet early stopping. Best iteration is:
# [498]	valid's rmse: 0.233367
# best iteration is 498
# best score is 0.23336709176139842
# Best iterations:
# [500, 499, 498]

# %%
# Debug For Avito2018
train = pd.read_csv('../input/train.csv', usecols=['price', 'image_top_1', 'activation_date'], parse_dates=['activation_date'],
                    dtype={'price': 'float32', 'image_top_1': 'float32'})
train = train.fillna(0)
y = pd.read_csv('../input/train.csv', usecols=['deal_probability'])

training_index   = train.loc[train.activation_date <= pd.to_datetime('2017-03-26')].index
validation_index = train.loc[train.activation_date >= pd.to_datetime('2017-03-27')].index
split_indices = [[training_index, validation_index]]
train.drop(['activation_date'], axis=1, inplace=True)
gc.collect()

lgb_models = []
best_iters = []
feature_imp_split = []
feature_imp_gain = []
preds = pd.DataFrame()
predictors = train.columns.tolist()

print(predictors)
for count, indices in enumerate(split_indices):
    train_idx = indices[0]
    valid_idx = indices[1]
    Dtrain, Dvalid = get_lgb_train(train.iloc[train_idx,:], y.iloc[train_idx,:], train.iloc[valid_idx,:], y.iloc[valid_idx,:], predictors, categorical)
    del train, y; gc.collect()
    print(Dtrain.data.shape)
    print(Dvalid.data.shape)
    lgb_model, best_iter = get_lgb_model(Dtrain, Dvalid, numiter=100, isValid=True, randomseed=123)
    del Dtrain, Dvalid; gc.collect()

    test = pd.read_csv('../input/test.csv', usecols=['price', 'image_top_1'], dtype={'price': 'float32', 'image_top_1': 'float32'})
    preds['lgb_pred_kfold_'+str(count)] = lgb_model.predict(test[predictors], num_iteration=best_iter)
    del test; gc.collect()
    
    lgb_models.append(lgb_model)
    best_iters.append(best_iter)
    fcols = lgb_model.feature_name()
    fimps = lgb_model.feature_importance(importance_type='split')
    feature_imp_split.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})
    fimps = lgb_model.feature_importance(importance_type='gain')
    feature_imp_gain.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})
    
    train = pd.read_csv('../input/train.csv', usecols=['price', 'image_top_1'], dtype={'price': 'float32', 'image_top_1': 'float32'})
    train = train.fillna(0)
    y = pd.read_csv('../input/train.csv', usecols=['deal_probability'])

del train, y
gc.collect()

print('Best iterations:')
print(best_iters)
print('Feature Importtance Split')
print(feature_imp_split)
print('Feature Importtance Gain')
print(feature_imp_gain)

subs = pd.read_csv('../input/test.csv', usecols=['item_id'])

pred_ensemble = np.zeros_like(preds['lgb_pred_kfold_0'].values)
for col in preds.columns:
    pred_ensemble += preds[col].values
pred_ensemble /= np.float(NFOLDS)
pred_ensemble = np.clip(pred_ensemble, 0, 1)
subs['deal_probability'] = pred_ensemble.flatten()

datetime = dt.now().strftime('%Y_%m%d_%H%M_%S')
fileprefix = '../subs/lightgbm_kfold_ensemble_'
filename = fileprefix+datetime+'.csv.gz'
subs.to_csv(filename, index=False, float_format='%.9f', compression='gzip',)
with open(fileprefix+datetime+'_fimp_split.pickle', 'wb') as f:
    pickle.dump(feature_imp_split, f)
with open(fileprefix+datetime+'_fimp_gain.pickle', 'wb') as f:
    pickle.dump(feature_imp_gain, f)
    
del subs, lgb_models, best_iters; gc.collect()

print('done')
# Out:
# ['price', 'image_top_1']
# (1275576, 2)
# (227848, 2)
# C:\Users\osk\Anaconda3\envs\InqueryAnalysis\lib\site-packages\lightgbm\basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds.
# [50]	valid's rmse: 0.249281
# [100]	valid's rmse: 0.245912
# Did not meet early stopping. Best iteration is:
# [100]	valid's rmse: 0.245912
# best iteration is 100
# best score is 0.24591241735375752
# Best iterations:
# [100]
# Feature Importtance Split
# [{'price': 12700, 'image_top_1': 12700}]
# Feature Importtance Gain
# [{'price': 36118.481109723456, 'image_top_1': 157664.50829423135}]
# done

# %%
# Debug
train = pd.read_csv('../input/train.csv', usecols=['price', 'image_top_1'], nrows=100000, dtype={'price': 'float32', 'image_top_1': 'float32'})
train = train.fillna(0)
y = pd.read_csv('../input/train.csv', usecols=['deal_probability'], nrows=100000)
predictors = train.columns.tolist()

skf = KFold(n_splits=2)
lgb_models = []
best_iters = []
feature_imp_split = []
feature_imp_gain = []
preds = pd.DataFrame()
count = 0

print(predictors)
for count, indices in enumerate(skf.split(train, y)):
    train_idx = indices[0]
    valid_idx = indices[1]
    Dtrain, Dvalid = get_lgb_train(train.iloc[train_idx,:], y.iloc[train_idx,:], train.iloc[valid_idx,:], y.iloc[valid_idx,:], predictors, categorical)
    del train, y; gc.collect()
    lgb_model, best_iter = get_lgb_model(Dtrain, Dvalid, numiter=200, isValid=True, randomseed=34+count)
    del Dtrain, Dvalid; gc.collect()

    test = pd.read_csv('../input/test.csv', usecols=['price', 'image_top_1'], nrows=100000, dtype={'price': 'float32', 'image_top_1': 'float32'})
    preds['lgb_pred_kfold_'+str(count)] = lgb_model.predict(test[predictors], num_iteration=best_iter)
    del test; gc.collect()
    
    lgb_models.append(lgb_model)
    best_iters.append(best_iter)
    fcols = lgb_model.feature_name()
    fimps = lgb_model.feature_importance(importance_type='split')
    feature_imp_split.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})
    fimps = lgb_model.feature_importance(importance_type='gain')
    feature_imp_gain.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})

    train = pd.read_csv('../input/train.csv', usecols=['price', 'image_top_1'], nrows=100000, dtype={'price': np.float32, 'image_top_1': np.float32})
    train.fillna(0)
    y = pd.read_csv('../input/train.csv', usecols=['deal_probability'], nrows=100000)

del train, y
gc.collect()

print('Best iterations:')
print(best_iters)
print('Feature Importtance Split')
print(feature_imp_split)
print('Feature Importtance Gain')
print(feature_imp_gain)

subs = pd.read_csv('../input/test.csv', usecols=['item_id'], nrows=100000)

pred_ensemble = np.zeros_like(preds['lgb_pred_kfold_0'].values)
for col in preds.columns:
    pred_ensemble += preds[col].values
pred_ensemble /= np.float(NFOLDS)
pred_ensemble = np.clip(pred_ensemble, 0, 1)
subs['deal_probability'] = pred_ensemble.flatten()

datetime = dt.now().strftime('%Y_%m%d_%H%M_%S')
fileprefix = '../subs/lightgbm_kfold_ensemble_'
filename = fileprefix+datetime+'.csv.gz'
subs.to_csv(filename, index=False, float_format='%.9f', compression='gzip')
with open(fileprefix+datetime+'_fimp_split.pickle', 'wb') as f:
    pickle.dump(feature_imp_split, f)
with open(fileprefix+datetime+'_fimp_gain.pickle', 'wb') as f:
    pickle.dump(feature_imp_gain, f)


del subs, lgb_models, best_iters; gc.collect()

print('done')
# Out:
# ['price', 'image_top_1']
# Training until validation scores don't improve for 50 rounds.
# C:\Users\osk\Anaconda3\envs\InqueryAnalysis\lib\site-packages\lightgbm\basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [50]	valid's rmse: 0.252395
# [100]	valid's rmse: 0.249167
# [150]	valid's rmse: 0.247827
# [200]	valid's rmse: 0.247183
# Did not meet early stopping. Best iteration is:
# [200]	valid's rmse: 0.247183
# best iteration is 200
# best score is 0.24718323691465693
# Training until validation scores don't improve for 50 rounds.
# [50]	valid's rmse: 0.25197
# [100]	valid's rmse: 0.248738
# [150]	valid's rmse: 0.247407
# [200]	valid's rmse: 0.246756
# Did not meet early stopping. Best iteration is:
# [200]	valid's rmse: 0.246756
# best iteration is 200
# best score is 0.24675563269041953
# Best iterations:
# [200, 200]
# Best iterations:
# [200, 200]
# Feature Importtance Split
# [{'price': 23592, 'image_top_1': 25400}, {'price': 23796, 'image_top_1': 25300}]
# Feature Importtance Gain
# [{'price': 2194.758231840886, 'image_top_1': 7967.553445522879}, {'price': 2240.092510456321, 'image_top_1': 7950.578621412944}]
# done

# %%
# Debug
# Example For whole traindata
bestiter = 500
train = pd.read_csv('../input/train.csv', usecols=['price', 'image_top_1'], nrows=100000, dtype={'price': 'float32', 'image_top_1': 'float32'})
train = train.fillna(0)
y = pd.read_csv('../input/train.csv', usecols=['deal_probability'], nrows=100000)
predictors = train.columns.tolist()

Dtrain, Dvalid = get_lgb_train(train, y, train.iloc[:2, :], y.iloc[:2, :], predictors, categorical)
del train, y; gc.collect()
numiter = np.uint(bestiter*1.1)
lgb_model, best_iter = get_lgb_model(Dtrain, Dvalid, numiter=numiter, isValid=False, randomseed=87)
del Dtrain; gc.collect()

feature_imp_split = []
feature_imp_gain = []
fcols = lgb_model.feature_name()
fimps = lgb_model.feature_importance(importance_type='split')
feature_imp_split.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})
fimps = lgb_model.feature_importance(importance_type='gain')
feature_imp_gain.append({fcol: fimp for fimp, fcol in zip(fimps, fcols)})

print('Feature Importtance Split')
print(feature_imp_split)
print('Feature Importtance Gain')
print(feature_imp_gain)

subs = pd.read_csv('../input/test.csv', usecols=['item_id'], nrows=100000)
test = pd.read_csv('../input/test.csv', usecols=['price', 'image_top_1'], nrows=100000, dtype={'price': 'float32', 'image_top_1': 'float32'})
subs['deal_probability'] = lgb_model.predict(test[predictors], num_iteration=best_iter)

datetime = dt.now().strftime('%Y_%m%d_%H%M_%S')
fileprefix = '../subs/lightgbm_kfold_ensemble_'
filename = fileprefix+datetime+'.csv.gz'
subs.to_csv(filename, index=False, float_format='%.9f', compression='gzip')
with open(fileprefix+datetime+'_fimp_split.pickle', 'wb') as f:
    pickle.dump(feature_imp_split, f)
with open(fileprefix+datetime+'_fimp_gain.pickle', 'wb') as f:
    pickle.dump(feature_imp_gain, f)

del subs, test; gc.collect()
# Out:
# C:\Users\osk\Anaconda3\envs\InqueryAnalysis\lib\site-packages\lightgbm\basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [100]	valid's rmse: 0.0955291
# [200]	valid's rmse: 0.0931288
# [300]	valid's rmse: 0.0910921
# [400]	valid's rmse: 0.0892808
# [500]	valid's rmse: 0.0880774
# best iteration is 0
# Feature Importtance Split
# [{'price': 69378, 'image_top_1': 69850}]
# Feature Importtance Gain
# [{'price': 5044.724804333292, 'image_top_1': 17115.593785221972}]
# 37
